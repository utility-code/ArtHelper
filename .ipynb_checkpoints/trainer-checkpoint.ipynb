# %% [markdown]
# # Imports

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import confusion_matrix
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob

# %%
root_dir = "/media/hdd/Datasets/Landscapes"
path=Path(root_dir)/"sorted"

# %%
files= glob.glob(str(path)+"*/*/*")

# %%
# failed = verify_images(files)
# failed

# %%
# failed = [Path.unlink(x) for x in failed]

# %% [markdown]
# # Setting Up Data

# %%
fields = DataBlock(blocks=(ImageBlock, CategoryBlock),
   get_items=get_image_files,
   get_y=parent_label,
   splitter=RandomSplitter(valid_pct=0.2, seed=42),
   item_tfms=RandomResizedCrop(128, min_scale=0.5),
   batch_tfms=aug_transforms(),
   )

# %%
dls = fields.dataloaders(path,bs = 5)

# %%
dls.vocab
# Out:
# ['Animals', 'Architecture', 'Armor', 'Desert', 'Fields', 'Flowers', 'Food', 'Forest', 'Mech', 'Mountain', 'People', 'Statues', 'Water', 'birds']

# %%
dls.show_batch()

# %% [markdown]
# # Training Pipeline

# %% [markdown]
# ## First Train

# %%
learn = vision_learner(dls, resnet34 , metrics = [error_rate, accuracy])

# %%
learn.fine_tune(4,base_lr=0.001)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.273319</td>
#       <td>0.584111</td>
#       <td>0.146747</td>
#       <td>0.853253</td>
#       <td>00:36</td>
#     </tr>
#   </tbody>
# </table>
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.072733</td>
#       <td>0.357793</td>
#       <td>0.101362</td>
#       <td>0.898638</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.703386</td>
#       <td>0.267006</td>
#       <td>0.078669</td>
#       <td>0.921331</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.676888</td>
#       <td>0.222134</td>
#       <td>0.059002</td>
#       <td>0.940998</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.516674</td>
#       <td>0.231378</td>
#       <td>0.072617</td>
#       <td>0.927383</td>
#       <td>00:47</td>
#     </tr>
#   </tbody>
# </table>
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
# cleaner = ImageClassifierCleaner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /home/eragon/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
# cleaner
# Out:
# VBox(children=(Dropdown(index=13, options=('Animals', 'Architecture', 'Armor', 'Desert', 'Fields', 'Flowers', …

# %%
objs = iter(os.listdir(Path(root_dir)/"unlabelled"))

# %%
learn.predict(Path(root_dir)/"unlabelled"/next(objs))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Architecture',
#  TensorBase(1),
#  TensorBase([2.7819e-01, 6.7158e-01, 1.2396e-03, 3.5088e-03, 3.6810e-03, 9.5963e-04,
#          1.0455e-03, 4.9111e-03, 9.9366e-03, 2.9779e-03, 4.8038e-05, 4.0641e-04,
#          1.8855e-02, 2.6581e-03]))

# %%
def one_batch(learn, iterator, no_items = 10):
    return [learn.predict(os.listdir(Path(root_dir)/"unlabelled"/next(iterator)) for _ in range(no_items)]

# %%
one_batch(learn, objs, 10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 one_batch(learn, objs, 10)
#
# Input In [52], in one_batch(learn, iterator, no_items)
#       1 def one_batch(learn, iterator, no_items = 10):
# ----> 2     return [learn.predict(next(iterator)) for _ in range(no_items)]
#
# Input In [52], in <listcomp>(.0)
#       1 def one_batch(learn, iterator, no_items = 10):
# ----> 2     return [learn.predict(next(iterator)) for _ in range(no_items)]
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/learner.py:288, in Learner.predict(self, item, rm_type_tfms, with_input)
#     286 def predict(self, item, rm_type_tfms=None, with_input=False):
#     287     dl = self.dls.test_dl([item], rm_type_tfms=rm_type_tfms, num_workers=0)
# --> 288     inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#     289     i = getattr(self.dls, 'n_inp', -1)
#     290     inp = (inp,) if i==1 else tuplify(inp)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/learner.py:275, in Learner.get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     273 if with_loss: ctx_mgrs.append(self.loss_not_reduced())
#     274 with ContextManagers(ctx_mgrs):
# --> 275     self._do_epoch_validate(dl=dl)
#     276     if act is None: act = getcallable(self.loss_func, 'activation')
#     277     res = cb.all_tensors()
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/learner.py:221, in Learner._do_epoch_validate(self, ds_idx, dl)
#     219 if dl is None: dl = self.dls[ds_idx]
#     220 self.dl = dl
# --> 221 with torch.no_grad(): self._with_events(self.all_batches, 'validate', CancelValidException)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/learner.py:179, in Learner._with_events(self, f, event_type, ex, final)
#     178 def _with_events(self, f, event_type, ex, final=noop):
# --> 179     try: self(f'before_{event_type}');  f()
#     180     except ex: self(f'after_cancel_{event_type}')
#     181     self(f'after_{event_type}');  final()
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/learner.py:185, in Learner.all_batches(self)
#     183 def all_batches(self):
#     184     self.n_iter = len(self.dl)
# --> 185     for o in enumerate(self.dl): self.one_batch(*o)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/load.py:132, in DataLoader.__iter__(self)
#     130 self.before_iter()
#     131 self.__idxs=self.get_idxs() # called in context of main process (not workers/subprocesses)
# --> 132 for b in _loaders[self.fake_l.num_workers==0](self.fake_l):
#     133     # pin_memory causes tuples to be converted to lists, so convert them back to tuples
#     134     if self.pin_memory and type(b) == list: b = tuple(b)
#     135     if self.device is not None: b = to_device(b, self.device)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/torch/utils/data/dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     528 if self._sampler_iter is None:
#     529     self._reset()
# --> 530 data = self._next_data()
#     531 self._num_yielded += 1
#     532 if self._dataset_kind == _DatasetKind.Iterable and \
#     533         self._IterableDataset_len_called is not None and \
#     534         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/torch/utils/data/dataloader.py:570, in _SingleProcessDataLoaderIter._next_data(self)
#     568 def _next_data(self):
#     569     index = self._next_index()  # may raise StopIteration
# --> 570     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     571     if self._pin_memory:
#     572         data = _utils.pin_memory.pin_memory(data)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:39, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      37         raise StopIteration
#      38 else:
# ---> 39     data = next(self.dataset_iter)
#      40 return self.collate_fn(data)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/load.py:143, in DataLoader.create_batches(self, samps)
#     141 if self.dataset is not None: self.it = iter(self.dataset)
#     142 res = filter(lambda o:o is not None, map(self.do_item, samps))
# --> 143 yield from map(self.do_batch, self.chunkify(res))
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastcore/basics.py:219, in chunked(it, chunk_sz, drop_last, n_chunks)
#     217 if not isinstance(it, Iterator): it = iter(it)
#     218 while True:
# --> 219     res = list(itertools.islice(it, chunk_sz))
#     220     if res and (len(res)==chunk_sz or not drop_last): yield res
#     221     if len(res)<chunk_sz: return
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/load.py:158, in DataLoader.do_item(self, s)
#     157 def do_item(self, s):
# --> 158     try: return self.after_item(self.create_item(s))
#     159     except SkipItemException: return None
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/load.py:165, in DataLoader.create_item(self, s)
#     164 def create_item(self, s):
# --> 165     if self.indexed: return self.dataset[s or 0]
#     166     elif s is None:  return next(self.it)
#     167     else: raise IndexError("Cannot index an iterable dataset numerically - must use `None`.")
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/core.py:458, in Datasets.__getitem__(self, it)
#     457 def __getitem__(self, it):
# --> 458     res = tuple([tl[it] for tl in self.tls])
#     459     return res if is_indexer(it) else list(zip(*res))
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/core.py:458, in <listcomp>(.0)
#     457 def __getitem__(self, it):
# --> 458     res = tuple([tl[it] for tl in self.tls])
#     459     return res if is_indexer(it) else list(zip(*res))
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/core.py:417, in TfmdLists.__getitem__(self, idx)
#     415 res = super().__getitem__(idx)
#     416 if self._after_item is None: return res
# --> 417 return self._after_item(res) if is_indexer(idx) else res.map(self._after_item)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/data/core.py:377, in TfmdLists._after_item(self, o)
# --> 377 def _after_item(self, o): return self.tfms(o)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastcore/transform.py:200, in Pipeline.__call__(self, o)
# --> 200 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastcore/transform.py:150, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     148 for f in tfms:
#     149     if not is_enc: f = f.decode
# --> 150     x = f(x, **kwargs)
#     151 return x
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastcore/transform.py:73, in Transform.__call__(self, x, **kwargs)
# ---> 73 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastcore/transform.py:83, in Transform._call(self, fn, x, split_idx, **kwargs)
#      81 def _call(self, fn, x, split_idx=None, **kwargs):
#      82     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 83     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastcore/transform.py:89, in Transform._do_call(self, f, x, **kwargs)
#      87     if f is None: return x
#      88     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 89     return retain_type(f(x, **kwargs), x, ret)
#      90 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#      91 return retain_type(res, x)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastcore/dispatch.py:123, in TypeDispatch.__call__(self, *args, **kwargs)
#     121 elif self.inst is not None: f = MethodType(f, self.inst)
#     122 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 123 return f(*args, **kwargs)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/vision/core.py:120, in PILBase.create(cls, fn, **kwargs)
#     118 if isinstance(fn,ndarray): return cls(Image.fromarray(fn))
#     119 if isinstance(fn,bytes): fn = io.BytesIO(fn)
# --> 120 return cls(load_image(fn, **merge(cls._open_args, kwargs)))
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/fastai/vision/core.py:95, in load_image(fn, mode)
#      93 def load_image(fn, mode=None):
#      94     "Open and load a `PIL.Image` and convert to `mode`"
# ---> 95     im = Image.open(fn)
#      96     im.load()
#      97     im = im._new(im.im)
#
# File ~/mambaforge/envs/pytorcher/lib/python3.10/site-packages/PIL/Image.py:3068, in open(fp, mode, formats)
#    3065     filename = fp
#    3067 if filename:
# -> 3068     fp = builtins.open(filename, "rb")
#    3069     exclusive_fp = True
#    3071 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '69307_478356087525_637272525_7000834_577847_n.jpg'

# %%
def predict_multiple(items, no)

# %% [markdown]
# # Iterative Training

# %%
# def run_iter_process(learn):
import qsl
from IPython.display import display

# %%
labeler = qsl.MediaLabeler(
    items=[
